# %%
import numpy as np
import cv2

# %%
img  = cv2.imread('./images/2200.jpg')
print(img)
# Out:
# [[[ 71 138 123]
#   [ 71 138 123]
#   [ 71 138 123]
#   ...
#   [ 70 145 124]
#   [ 70 145 124]
#   [ 70 145 124]]
#
#  [[ 71 138 123]
#   [ 71 138 123]
#   [ 71 138 123]
#   ...
#   [ 70 145 124]
#   [ 70 145 124]
#   [ 70 145 124]]
#
#  [[ 71 138 123]
#   [ 71 138 123]
#   [ 71 138 123]
#   ...
#   [ 70 145 124]
#   [ 70 145 124]
#   [ 70 145 124]]
#
#  ...
#
#  [[105 153 141]
#   [105 153 141]
#   [105 153 141]
#   ...
#   [119 158 160]
#   [124 161 165]
#   [124 161 165]]
#
#  [[103 151 139]
#   [103 151 139]
#   [103 151 139]
#   ...
#   [117 156 158]
#   [123 160 164]
#   [123 160 164]]
#
#  [[104 152 140]
#   [104 152 140]
#   [104 152 140]
#   ...
#   [114 155 157]
#   [121 158 162]
#   [121 158 162]]]

# %%
img.max()
img.min()
img.shape
# Out:
# (534, 890, 3)

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
cv2.imshow("NEW", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img[:, :, [2, 1, 0]])
plt.show()
